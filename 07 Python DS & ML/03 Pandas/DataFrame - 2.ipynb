# %%
import numpy as np

# %%
import pandas as pd

# %%
from numpy.random import randn

# %%
outside = ['G1','G1','G1','G2','G2','G2']
inside  = [1,2,3,1,2,3]
hier_index =  list(zip(outside,inside))
heir_index = pd.MultiIndex.from_tuples(hier_index)

# %%
outside
# Out:
# ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']

# %%
inside
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
heir_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
list(zip(outside,inside))
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
df = pd.DataFrame(randn(6,2),heir_index,['A','B'])

# %%
df
# Out:
#              A         B
# G1 1 -0.205655  0.681463
#    2  0.891655 -1.181928
#    3  0.889789  0.248071
# G2 1 -0.832184  1.096744
#    2 -0.031514  0.130282
#    3  0.178602  0.057691

# %%
df.loc['G1'].loc[1]
# Out:
# A   -0.205655
# B    0.681463
# Name: 1, dtype: float64

# %%
df.index.names = ['Groups','Num']

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1   -0.205655  0.681463
#        2    0.891655 -1.181928
#        3    0.889789  0.248071
# G2     1   -0.832184  1.096744
#        2   -0.031514  0.130282
#        3    0.178602  0.057691

# %%
df.loc['G2'].loc[2]
# Out:
# A   -0.031514
# B    0.130282
# Name: 2, dtype: float64
