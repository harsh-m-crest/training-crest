# %% [markdown]
# # Check for Leap Year:

# %%
# !pip install pendulum
import pendulum
# Out:
# Requirement already satisfied: pendulum in c:\users\harshmistry\anaconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: python-dateutil>=2.6 in c:\users\harshmistry\anaconda3\lib\site-packages (from pendulum) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2020.1 in c:\users\harshmistry\anaconda3\lib\site-packages (from pendulum) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\harshmistry\anaconda3\lib\site-packages (from python-dateutil>=2.6->pendulum) (1.17.0)

# %%
import calendar 

current_year = pendulum.now().year

is_leap_year = calendar.isleap(current_year)

if is_leap_year:
    print(f"{current_year}  is a leap year..")
else:
    print(f"{current_year} is not a leap year.")
# Out:
# 2026 is not a leap year.

# %% [markdown]
# # Is it Weekday or Weekend ?

# %%
def isweekend(d):
    if d>=1 and d <=5:
        print("It's a weekday.")
    else:
        print("Enjoy the weekend")

isweekend(pendulum.now().day_of_week)
# Out:
# It's a weekday.
