# %% [markdown]
# # Ex - 1: find all the numbers in a given string and print them

# %%
#Input: abcd11gdf15hnnn678hh4 
#Output: 11 15 678 4 

import re
str = 'abcd11gdf15hnnn678hh4'

pattern  ='\d+'

result = re.findall(pattern,str)

result
# Out:
# ['11', '15', '678', '4']

# %% [markdown]
# # Ex - 2: Use Regex to validate a password

# %%
s = 'asdab@!234'
ps = 'R@m@_f0rtu9e$'

pattern = r'^[a-z]+[!@#$%&]+\d+$'
print(bool(re.match(pattern, ps)))
# Out:
# False

# %% [markdown]
# # Ex - 3: Find the type of IP Address using Regex

# %%
# ip = '192.0.2.126'
#ip = '3001:0da8:75a3:0000:0000:8a2e:0370:7334'
# ip = '36.12.08.20.52'

ip = input("Enter an ip address to check whether it is IPv4 or IPv6 or Invalid : ")

ipv4_pattern = r'^((25[0-5]|2[0-4]\d|1\d\d|[1-9]?\d)\.){3}(25[0-5]|2[0-4]\d|1\d\d|[1-9]?\d)$'
ipv6_pattern = r'^([0-9a-fA-F]{1,4}:){7}[0-9a-fA-F]{1,4}$'

if re.match(ipv4_pattern, ip):
    print("IPv4")
elif re.match(ipv6_pattern, ip):
    print("IPv6")
else:
    print("Invalid")
# Out:
# Enter an ip address to check whether it is IPv4 or IPv6 or Invalid :  3001:0da8:75a3:0000:0000:8a2e:0370:7334
# IPv6
