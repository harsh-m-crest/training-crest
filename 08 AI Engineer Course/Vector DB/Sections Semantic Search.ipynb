# %%
# %load_ext dotenv
# %dotenv

# %%
import pandas as pd
import os
from pinecone import Pinecone, ServerlessSpec
from dotenv import load_dotenv, find_dotenv
import pinecone
from sentence_transformers import SentenceTransformer

# %%
files = pd.read_csv("course_section_descriptions.csv", encoding="ANSI")
files.head()
# Out:
#    course_id  ...                                section_description
# 0          2  ...  While Tableau is an indispensable tool in the ...
# 1          2  ...  In this section, you will create your first Ta...
# 2          2  ...  This section is a practical example that will ...
# 3          3  ...  In this section, you will learn about the impo...
# 4          3  ...  Here, we set up different environments for the...
#
# [5 rows x 11 columns]

# %%
files["unique_id"] = files["course_id"].astype(str) + '-' + files["section_id"].astype(str)

# %%
files["metadata"] = files.apply(lambda row: {
    "course_name" : row["course_name"],
    "section_name" : row["section_name"],
    "section_description": row["section_description"],
}, axis = 1)

# %%
def create_embeddings(row):
    combined_text = f'''{row["course_name"]} {row["course_name"]}
                        {row["course_description"]}{row["section_name"]}{row["section_description"]}'''
    return model.encode(combined_text, show_progress_bar = False)

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights: 100%|█| 103/103 [00:00<00:00, 181.64it/s, Materializing
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
