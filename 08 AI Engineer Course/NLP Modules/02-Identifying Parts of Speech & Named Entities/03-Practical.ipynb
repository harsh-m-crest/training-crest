# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
bbc_data = pd.read_csv("bbc_news.csv")

# %%
bbc_data.head()
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0   6684                              Can I refuse to work?
# 1           1   9267  'Liz Truss the Brief?' World reacts to UK poli...
# 2           2   7387  Rationing energy is nothing new for off-grid c...
# 3           3    767  The hunt for superyachts of sanctioned Russian...
# 4           4   3712  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                          pubDate  \
# 0  Wed, 10 Aug 2022 15:46:18 GMT
# 1  Mon, 17 Oct 2022 11:35:12 GMT
# 2  Wed, 31 Aug 2022 05:20:18 GMT
# 3  Tue, 22 Mar 2022 14:37:01 GMT
# 4  Wed, 01 Jun 2022 23:17:33 GMT
#
#                                                 guid  \
# 0       https://www.bbc.co.uk/news/business-62147992
# 1          https://www.bbc.co.uk/news/world-63285480
# 2  https://www.bbc.co.uk/news/uk-scotland-highlan...
# 3                https://www.bbc.co.uk/news/60739336
# 4             https://www.bbc.co.uk/news/uk-61660128
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/business-62147992?a...
# 1  https://www.bbc.co.uk/news/world-63285480?at_m...
# 2  https://www.bbc.co.uk/news/uk-scotland-highlan...
# 3  https://www.bbc.co.uk/news/60739336?at_medium=...
# 4  https://www.bbc.co.uk/news/uk-61660128?at_medi...
#
#                                          description
# 0  With much of the UK enduring another period of...
# 1  The UK's political chaos has been watched arou...
# 2  Scoraig in the north west Highlands has long h...
# 3  Wealthy Russians sanctioned by the US, EU and ...
# 4  A quick look back at the Queen's 70 years on t...

# %%
bbc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   index        1000 non-null   int64
#  2   title        1000 non-null   object
#  3   pubDate      1000 non-null   object
#  4   guid         1000 non-null   object
#  5   link         1000 non-null   object
#  6   description  1000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
titles = pd.DataFrame(bbc_data['title'])
titles.head()
# Out:
#                                                title
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...

# %% [markdown]
# # Clean data

# %%
titles['lowercase'] = titles['title'].str.lower()
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...

# %%
en_stopwords = stopwords.words('english')
titles['no_stopwords'] = titles['lowercase'].apply(lambda x: ' '.join([word for word in x.split() if word not in (en_stopwords)]))
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds

# %%
titles['no_stopwords_no_punct'] = titles.apply(lambda x: re.sub(r"([^\w\s])", "", x['no_stopwords']), axis=1)
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                                no_stopwords_no_punct
# 0                                        refuse work
# 1  liz truss brief world reacts uk political turmoil
# 2     rationing energy nothing new offgrid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4         platinum jubilee 70 years queen 70 seconds

# %%
titles['tokens_raw'] = titles.apply(lambda x: word_tokenize(x['title']), axis=1)
titles['tokens_clean'] = titles.apply(lambda x: word_tokenize(x['no_stopwords_no_punct']), axis=1)
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                                no_stopwords_no_punct  \
# 0                                        refuse work
# 1  liz truss brief world reacts uk political turmoil
# 2     rationing energy nothing new offgrid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4         platinum jubilee 70 years queen 70 seconds
#
#                                           tokens_raw  \
# 0                      [Can, I, refuse, to, work, ?]
# 1  ['Liz, Truss, the, Brief, ?, ', World, reacts,...
# 2  [Rationing, energy, is, nothing, new, for, off...
# 3  [The, hunt, for, superyachts, of, sanctioned, ...
# 4  [Platinum, Jubilee, :, 70, years, of, the, Que...
#
#                                         tokens_clean
# 0                                     [refuse, work]
# 1  [liz, truss, brief, world, reacts, uk, politic...
# 2  [rationing, energy, nothing, new, offgrid, com...
# 3  [hunt, superyachts, sanctioned, russian, oliga...
# 4  [platinum, jubilee, 70, years, queen, 70, seco...

# %%
lemmatizer = WordNetLemmatizer()
titles["tokens_clean_lemmatized"] = titles["tokens_clean"].apply(lambda tokens: [lemmatizer.lemmatize(token) for token in tokens])
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                                no_stopwords_no_punct  \
# 0                                        refuse work
# 1  liz truss brief world reacts uk political turmoil
# 2     rationing energy nothing new offgrid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4         platinum jubilee 70 years queen 70 seconds
#
#                                           tokens_raw  \
# 0                      [Can, I, refuse, to, work, ?]
# 1  ['Liz, Truss, the, Brief, ?, ', World, reacts,...
# 2  [Rationing, energy, is, nothing, new, for, off...
# 3  [The, hunt, for, superyachts, of, sanctioned, ...
# 4  [Platinum, Jubilee, :, 70, years, of, the, Que...
#
#                                         tokens_clean  \
# 0                                     [refuse, work]
# 1  [liz, truss, brief, world, reacts, uk, politic...
# 2  [rationing, energy, nothing, new, offgrid, com...
# 3  [hunt, superyachts, sanctioned, russian, oliga...
# 4  [platinum, jubilee, 70, years, queen, 70, seco...
#
#                              tokens_clean_lemmatized
# 0                                     [refuse, work]
# 1  [liz, truss, brief, world, reacts, uk, politic...
# 2  [rationing, energy, nothing, new, offgrid, com...
# 3  [hunt, superyachts, sanctioned, russian, oliga...
# 4   [platinum, jubilee, 70, year, queen, 70, second]

# %%
tokens_raw_list = sum(titles['tokens_raw'], [])
tokens_clean_list = sum(titles['tokens_clean_lemmatized'], [])

# %% [markdown]
# # POS Tagging

# %%
nlp = spacy.load('en_core_web_sm')

# %%
spacy_doc = nlp(''.join(tokens_raw_list))

# %%
pos_df = pd.DataFrame(columns=['token', 'pos_tag'])

for token in spacy_doc:
    pos_df = pd.concat([pos_df,
                       pd.DataFrame.from_records([{'token': token.text,'pos_tag': token.pos_}])], ignore_index=True)

# %%
pos_df_counts = pos_df.groupby(['token','pos_tag']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)
pos_df_counts.head(10)
# Out:
#            token pos_tag  counts
# 39             :   PUNCT     498
# 2              -   PUNCT     202
# 0              ,   PUNCT      81
# 1              -    NOUN       6
# 791         year    NOUN       4
# 3              .   PUNCT       3
# 615            a     DET       3
# 621  andwhowon't   PROPN       2
# 586      Whowill    NOUN       2
# 23   1RealMadrid     NUM       2

# %%
pos_df_counts = pos_df.groupby(['token','pos_tag']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)
pos_df_counts.head(10)
# Out:
#            token pos_tag  counts
# 39             :   PUNCT     498
# 2              -   PUNCT     202
# 0              ,   PUNCT      81
# 1              -    NOUN       6
# 791         year    NOUN       4
# 3              .   PUNCT       3
# 615            a     DET       3
# 621  andwhowon't   PROPN       2
# 586      Whowill    NOUN       2
# 23   1RealMadrid     NUM       2

# %%
verbs = pos_df_counts[pos_df_counts.pos_tag == "VERB"][0:10]
verbs
# Out:
#                                                  token pos_tag  counts
# 454  SouthAsianfacesonTV'makesmehappy'PrinceHarryre...    VERB       1
# 728  readingcombatjetforthefutureEnglandscoringreco...    VERB       1
# 729                     rent‘ghostlandlords’TheHundred    VERB       1
# 758                                          streaming    VERB       1
# 751                       sayswatchdogMexicokidnapping    VERB       1
# 769  timeshowActorOrlandoBloommeetschildrenaffected...    VERB       1
# 760  stylefarewellasEuropeloseCelticeasebyDundeeUtd...    VERB       1
# 637  checkedDominicRaabfacesquestionsoveraggressive...    VERB       1
# 641                                    consumerswarned    VERB       1
# 606  WorkersvoteonfurthersixmonthsofwalkoutsEideval...    VERB       1

# %%
adj = pos_df_counts[pos_df_counts.pos_tag == "ADJ"][0:10]
adj
# Out:
#                                                  token pos_tag  counts
# 519  USOpenchampiondiscusses'tough'splitwithcoachTo...     ADJ       1
# 568                       Whattolookoutforinthequarter     ADJ       1
# 409  RivalryisfierceonthepitchbutfriendlyoffitChild...     ADJ       1
# 455              SouthKoreareachlast16withdramaticlast     ADJ       1
# 702                           myhusbandwillkillmeEarth     ADJ       1
# 714                               onlysuburbUkrainewar     ADJ       1
# 781                             uptrophyUlvadeshooting     ADJ       1
# 785  welterweightchampionFerrellshouldhavehadOscarn...     ADJ       1
# 640  circlemakerswho'blewpeople'sminds'King'scorona...     ADJ       1
# 607  WorkstartstocutdownBrettonoaktreeOnlinepredato...     ADJ       1

# %% [markdown]
# # NER

# %%
ner_df = pd.DataFrame(columns=['token', 'ner_tag'])

for token in spacy_doc.ents:
    if pd.isna(token.label_) is False:
        ner_df = pd.concat([ner_df, pd.DataFrame.from_records(
            [{'token': token.text, 'ner_tag': token.label_}])], ignore_index=True)

# %%
ner_df.head()
# Out:
#                                                token ner_tag
# 0                    DemocratselevatedthisRepublican     ORG
# 1  Dutch17-year-oldIsaacBabadiscoresPanenkapenalt...    DATE
# 2  Leicester16-6Edinburgh-JasperWiesetrysendsTige...     ORG
# 3                                              Gakpo     GPE
# 4                                sayLibDemsChrisKaba    NORP

# %%
ner_df_counts = ner_df.groupby(['token','ner_tag']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)
ner_df_counts.head(10)
# Out:
#                                                 token   ner_tag  counts
# 0                                          2Liverpool  CARDINAL       1
# 62  TributeshailFaithlesssingerasan'incredibletale...      NORP       1
# 60  TheLondonhighstreetvotedoneoftheworld'scoolest...       ORG       1
# 59                                      Tensewaitasex       GPE       1
# 58  Taiwanisina'Pelosilovefest'TrumpOrganizationfo...  CARDINAL       1
# 57                                             Taiwan       GPE       1
# 56                                           Sterling       ORG       1
# 55                                   Somefansmisskick    PERSON       1
# 54                                              Silva    PERSON       1
# 53                                              Salah      NORP       1

# %%
people = ner_df_counts[ner_df_counts.ner_tag == "PERSON"][0:10]
people
# Out:
#                                                 token ner_tag  counts
# 55                                   Somefansmisskick  PERSON       1
# 54                                              Silva  PERSON       1
# 52                                               Saka  PERSON       1
# 49  RehanAhmedcouldmakedebutinKarachiThewomanwhofo...  PERSON       1
# 48  RedsbeateninParisasViniciusJrhitswinnerHowmuch...  PERSON       1
# 46  Nursewholostherlegshasfirstdancewithhusbandinh...  PERSON       1
# 44   NasawilltrytolaunchMoonrocketonSaturdayElSistema  PERSON       1
# 42       MumseessonwalkforfirsttimeMatchoftheDayTop10  PERSON       1
# 79  saysCurtisRoyalMailworkerstohold19daysofstrike...  PERSON       1
# 75                 Womanwokeupwithfootballerrapingher  PERSON       1

# %%
people = ner_df_counts[ner_df_counts.ner_tag == "PERSON"][0:10]
people
# Out:
#                                                 token ner_tag  counts
# 55                                   Somefansmisskick  PERSON       1
# 54                                              Silva  PERSON       1
# 52                                               Saka  PERSON       1
# 49  RehanAhmedcouldmakedebutinKarachiThewomanwhofo...  PERSON       1
# 48  RedsbeateninParisasViniciusJrhitswinnerHowmuch...  PERSON       1
# 46  Nursewholostherlegshasfirstdancewithhusbandinh...  PERSON       1
# 44   NasawilltrytolaunchMoonrocketonSaturdayElSistema  PERSON       1
# 42       MumseessonwalkforfirsttimeMatchoftheDayTop10  PERSON       1
# 79  saysCurtisRoyalMailworkerstohold19daysofstrike...  PERSON       1
# 75                 Womanwokeupwithfootballerrapingher  PERSON       1

# %%
places = ner_df_counts[ner_df_counts.ner_tag == "GPE"][0:10]
places
# Out:
#                                                 token ner_tag  counts
# 59                                      Tensewaitasex     GPE       1
# 57                                             Taiwan     GPE       1
# 61  Theprotestsunifyinganationwhereethnicfaultline...     GPE       1
# 63  TyrrellHattonsecondInoneofthepoorestslumsinArg...     GPE       1
# 64     UK'hostage'tostrikesand'WorldCuplecrunch'China     GPE       1
# 72              WillandGracestardiesaged67OliviaPratt     GPE       1
# 37  Man,34,arrestedoverpolicescenefootageMazepin&f...     GPE       1
# 28                                              Gakpo     GPE       1
