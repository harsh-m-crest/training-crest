# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown , display

# %%
load_dotenv(override=True)
# Out:
# True

# %%
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openrouter_api_key:
    print(f"OpenAI APi Key exists and begins {openrouter_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the guides folder")
# Out:
# OpenAI APi Key exists and begins sk-or-v1

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=openrouter_api_key,
)

# %%
response = client.chat.completions.create(
    model="openai/gpt-4.1-nano",
    max_tokens=200,
    messages=messages,
)

#print(response.choices[0].message.content)

question = response.choices[0].message.content
print(question)
# Out:
# If a truth-teller always tells the truth and a liar always lies, and you encounter two individuals—one who always tells the truth and one who always lies—what single yes/no question can you ask either of them to determine which one is the truth-teller?

# %%
messages = [{"role":"user","content":question}]

response = client.chat.completions.create(
    model="openai/gpt-4.1-nano",
    messages=messages,
    max_tokens=200
)

answer= response.choices[0].message.content
display(Markdown(answer))
# Out:
# Here's a classic approach to identify the truth-teller with just one yes/no question:
#
# **Question:**
# *If I asked the other person whether you are the truth-teller, would they say "yes"?*
#
# ---
#
# ### Explanation:
#
# Suppose you ask this question to either individual (call them Person A). Remember:
# - The **truth-teller** always tells the truth.
# - The **liar** always lies.
#
# Consider the two cases:
#
# ---
#
# ### Case 1: You ask the **truth-teller**
# - Who are you? The truth-teller (say, Person A).
# - The other person (Person B) is the liar.
#
# **Question:** *If I asked the other person whether you are the truth-teller, would they say "yes"?*
#
# - Since Person B is the liar:
#   - If Person A **is** the truth-teller:
#     - The **liar** (Person B) **would** lie and say **"no

# %%
messages = [{"role":"user","content":question}]

response = client.chat.completions.create(
    model="anthropic/claude-sonnet-4.6",
    messages=messages,
    max_tokens=200
)
answer= response.choices[0].message.content
display(Markdown(answer))
# Out:
# ## The Classic Two-Guards Problem
#
# ### The Question
#
# Ask either person:
#
# > **"If I asked the other person whether you are the truth-teller, would they say yes?"**
#
# ---
#
# ### Why It Works
#
# Trace through both scenarios:
#
# | You ask the... | Their answer | Reasoning |
# |---|---|---|
# | **Truth-teller** | **No** | The liar *would* say "no" (a lie), so the truth-teller truthfully reports "no" |
# | **Liar** | **No** | The truth-teller *would* say "no" (honestly), so the liar *lies* and says "no" |
#
# ### The Key Insight
#
# The **double negative** creates a reliable signal:
# - The truth-teller tells the truth **about** the liar's lie → cancels out
# - The liar lies **about

# %%
messages = [{"role":"user","content":question}]

response = client.chat.completions.create(
    model="google/gemini-3-pro-preview",
    messages=messages,
    max_tokens=200
)
answer= response.choices[0].message.content
display(Markdown(answer))
# Out:
# The classic single yes/no question
