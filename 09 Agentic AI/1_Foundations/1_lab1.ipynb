# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openrouter_api_key:
    print(f"OpenAI APi Key exists and begins {openrouter_api_key}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the guides folder")
# Out:
# OpenAI APi Key exists and begins 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

# %%
from openai import OpenAI

# %%
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=openrouter_api_key,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 client = OpenAI(
#       2   base_url="https://openrouter.ai/api/v1",
#       3   api_key=openrouter_api_key,
#       4 )
#
# NameError: name 'OpenAI' is not defined

# %%
messages = [{
    "role":"user",
    "content":"Waht is 2+2"
}]

# %%
response = client.chat.completions.create(
    model="openai/gpt-4.1-nano",
    max_tokens=200,
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
response = client.chat.completions.create(
    model="openai/gpt-4.1-nano",
    max_tokens=200,
    messages=messages,
)

question = response.choices[0].message.content
print(question)
# Out:
# A bat and a ball together cost $1.10. The bat costs $1.00 more than the ball. How much does the ball cost?

# %%
messages = [{"role": "user", "content": question}]

# %%
response = client.chat.completions.create(
    model="openai/gpt-4.1-nano",
    max_tokens=200,
    messages=messages,
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's define the variables:
#
# - Let \( x \) be the cost of the ball.
# - Since the bat costs $1.00 more than the ball, the cost of the bat is \( x + 1.00 \).
#
# Given that the total cost of both is $1.10:
#
# \[
# x + (x + 1.00) = 1.10
# \]
#
# Combine like terms:
#
# \[
# 2x + 1.00 = 1.10
# \]
#
# Subtract 1.00 from both sides:
#
# \[
# 2x = 0.10
# \]
#
# Divide both sides by 2:
#
# \[
# x = 0.05
# \]
#
# **Answer: The ball costs \(\boxed{\$0.05}\).**

# %%
from IPython.display import Markdown , display

# %%
display(Markdown(answer))
# Out:
# Let's define the variables:
#
# - Let \( x \) be the cost of the ball.
# - Since the bat costs $1.00 more than the ball, the cost of the bat is \( x + 1.00 \).
#
# Given that the total cost of both is $1.10:
#
# \[
# x + (x + 1.00) = 1.10
# \]
#
# Combine like terms:
#
# \[
# 2x + 1.00 = 1.10
# \]
#
# Subtract 1.00 from both sides:
#
# \[
# 2x = 0.10
# \]
#
# Divide both sides by 2:
#
# \[
# x = 0.05
# \]
#
# **Answer: The ball costs \(\boxed{\$0.05}\).**

# %%
display(Markdown(answer))
# Out:
# Let's define the variables:
#
# - Let \( x \) be the cost of the ball.
# - Since the bat costs $1.00 more than the ball, the cost of the bat is \( x + 1.00 \).
#
# Given that the total cost of both is $1.10:
#
# \[
# x + (x + 1.00) = 1.10
# \]
#
# Combine like terms:
#
# \[
# 2x + 1.00 = 1.10
# \]
#
# Subtract 1.00 from both sides:
#
# \[
# 2x = 0.10
# \]
#
# Divide both sides by 2:
#
# \[
# x = 0.05
# \]
#
# **Answer: The ball costs \(\boxed{\$0.05}\).**
