# %%
import ipywidgets as widgets
from IPython.display import display

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
w.layout.margin = 'auto'

# %%
w.layout.height = '75px'

# %%
x = widgets.IntSlider(value=15,description='New Slider')

# %%
display(x)
x.layout = w.layout
# Out:
# IntSlider(value=15, description='New Slider')

# %%
widgets.Button(description='Ordinary Button',button_style='danger')
# Out:
# Button(button_style='danger', description='Ordinary Button', style=ButtonStyle())

# %%
widgets.Button(decription='Ordinary Button',button_style ='info')
# Out:
# Button(button_style='info', style=ButtonStyle())

# %%
widgets.Button(decription='Ordinary Button',button_style ='warning')
# Out:
# Button(button_style='warning', style=ButtonStyle())

# %%
widgets.Button(decription='Ordinary Button',button_style ='primary')
# Out:
# Button(button_style='primary', style=ButtonStyle())

# %%
widgets.Button(decription='Ordinary Button',button_style ='success')
# Out:
# Button(button_style='success', style=ButtonStyle())

# %%
b1 = widgets.Button(description = 'Custom Color')
b1.style.button_color = 'lightgreen'
b1
# Out:
# Button(description='Custom Color', style=ButtonStyle(button_color='lightgreen'))

# %%
b1.style.keys
# Out:
# ['_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'button_color',
#  'font_family',
#  'font_size',
#  'font_style',
#  'font_variant',
#  'font_weight',
#  'text_color',
#  'text_decoration']

# %%
b2 = widgets.Button(decription='NEW')
b2.style = b1.style
b2
# Out:
# Button(style=ButtonStyle(button_color='lightgreen'))

# %%
s1 = widgets.IntSlider(description='My Handle')
s1.style.handle_color = 'blue'
s1
# Out:
# IntSlider(value=0, description='My Handle', style=SliderStyle(handle_color='blue'))
