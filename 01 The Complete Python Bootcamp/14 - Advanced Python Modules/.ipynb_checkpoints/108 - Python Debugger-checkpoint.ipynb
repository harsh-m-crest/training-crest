# %%
x = [1,2,3]
y = 2
z = 3

# %%
import pdb

# %%
x=[1,2,3]
y=2
z=3

result_one = y + z

pdb.set_trace()
result_two = y + x
# Out:
# > c:\users\harshmistry\appdata\local\temp\ipykernel_5560\3952014374.py(7)<module>()
# ipdb>  x
# [1, 2, 3]
# ipdb>  result
# 5
# ipdb>  y
# 2
# ipdb>  x
# [1, 2, 3]
# ipdb>  x+y
# *** TypeError: can only concatenate list (not "int") to list
# ipdb>  q
