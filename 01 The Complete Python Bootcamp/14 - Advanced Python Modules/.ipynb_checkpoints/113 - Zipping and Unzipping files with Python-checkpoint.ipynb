# %%
f = open('fileone.txt','w+')
f.write('ONE FILE')
f.close()

# %%
f = open('filetwo.txt','w+')
f.write('TWo File')
f.close()

# %%
import zipfile

# %%
comp_file = zipfile.ZipFile('comp_file.zip','w')

# %%
comp_file.write('fileone.txt',compress_type=zipfile.ZIP_DEFLATED)

# %%
comp_file.write('filetwo.txt',compress_type=zipfile.ZIP_DEFLATED)

# %%
comp_file.close()

# %%
zip_obj = zipfile.ZipFile('comp_file.zip','r')

# %%
zip_obj.extractall('extracted_content')

# %%
pwd
# Out:
# 'C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp\\14 - Advanced Python Modules'

# %%
import shutil

# %%
dir_to_zip = "C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp\\14 - Advanced Python Modules\\extracted_content"

# %%
output_filename = 'example'

# %%
shutil.make_archive(output_filename,'zip',dir_to_zip)
# Out:
# 'C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp\\14 - Advanced Python Modules\\example.zip'

# %%
shutil.unpack_archive('example.zip','final_unzip','zip')
