# %%
pwd
# Out:
# 'C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp\\14 - Advanced Python Modules'

# %%
f = open('practise.txt','w+')
f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp\\14 - Advanced Python Modules'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '104 - Python Collections Module.ipynb',
#  '105 - Opening and Reading Files and Folders Python OS Module.ipynb',
#  'practise.txt']

# %%
os.listdir('c:\\Users')
# Out:
# ['All Users',
#  'CIPLADMIN',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'HarshMistry',
#  'Public']

# %%
import shutil

# %%
shutil.move('practise.txt','C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp')
# Out:
# 'C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp\\practise.txt'

# %%
os.listdir('C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp')
# Out:
# ['.ipynb_checkpoints',
#  '03 Python Objects and DataType',
#  '04 - Python Comparison Operators',
#  '05 - Python Statements',
#  '06 - Methods and Functions',
#  '07 - Miestone Project 1',
#  '08 - Object Oriented Programming',
#  '09 - Modules and Packages',
#  '10 - Errors and Exceptions Handling',
#  '11 - Milestone Project 2',
#  '12 - Python Decorators',
#  '13 - Python Generators',
#  '14 - Advanced Python Modules',
#  'practise.txt']

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '104 - Python Collections Module.ipynb',
#  '105 - Opening and Reading Files and Folders Python OS Module.ipynb']

# %%
shutil.move('C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp\\practise.txt',os.getcwd())
# Out:
# 'C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp\\14 - Advanced Python Modules\\practise.txt'

# %%
send2trash.send2trash('practise.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '104 - Python Collections Module.ipynb',
#  '105 - Opening and Reading Files and Folders Python OS Module.ipynb']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp\\14 - Advanced Python Modules'

# %%
file_path = 'C:\\Users\\HarshMistry\\training-crest\\01 The Complete Python Bootcamp'

# %%
for folder , sub_folders,files in os.walk(file_path):
    print(f'Currently Looking at {folder}')
    print('\n')
    print('The Subfolder  are:')
    for sub_fold in sub_folders:
        print( f'\t Subfolder: {sub_fold}')

    print('\n')
    print("the files are:")
    for f in files:
        print(f"\t File: {f}")
    print('\n')
# Out:
# Currently Looking at C:\Users\HarshMistry\training-crest\01 The Complete Python Bootcamp
#
#
# The Subfolder  are:
# 	 Subfolder: .ipynb_checkpoints
# 	 Subfolder: 03 Python Objects and DataType
# 	 Subfolder: 04 - Python Comparison Operators
# 	 Subfolder: 05 - Python Statements
# 	 Subfolder: 06 - Methods and Functions
# 	 Subfolder: 07 - Miestone Project 1
# 	 Subfolder: 08 - Object Oriented Programming
# 	 Subfolder: 09 - Modules and Packages
# 	 Subfolder: 10 - Errors and Exceptions Handling
# 	 Subfolder: 11 - Milestone Project 2
# 	 Subfolder: 12 - Python Decorators
# 	 Subfolder: 13 - Python Generators
# 	 Subfolder: 14 - Advanced Python Modules
#
#
# the files are:
#
#
# Currently Looking at C:\Users\HarshMistry\training-crest\01 The Complete Python Bootcamp\.ipynb_checkpoints
#
#
# The Subfolder  are:
#
#
# the files are:
#
#
# Currently Looking at C:\Users\HarshMistry\training-crest\01 The Complete Python Bootcamp\03 Python Objects and DataType
#
#
# The Subfolder  are:
# ...
