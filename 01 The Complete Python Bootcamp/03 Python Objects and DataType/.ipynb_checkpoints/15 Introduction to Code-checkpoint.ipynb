# %%
 'hello'
# Out:
# 'hello'

# %%
"hello"
# Out:
# 'hello'

# %%
"this is also a string"
# Out:
# 'this is also a string'

# %%
"I'm going on a run "
# Out:
# "I'm going on a run "

# %%
print("hello")
# Out:
# hello

# %%
"hello world one"
"hello world two"
# Out:
# 'hello world two'

# %%
print("Hello wolrd one")
print("Hello wolrd two")
# Out:
# Hello wolrd one
# Hello wolrd two

# %%
print("Hello \nWorld")
# Out:
# Hello
# World

# %%
print("Hello \tWorld")
# Out:
# Hello 	World

# %%
len("hello")
# Out:
# 5

# %%
len('I am')
# Out:
# 4
