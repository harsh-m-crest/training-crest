# %%
print('this is is a string {}'.format('INSERTED'))
# Out:
# this is is a string INSERTED

# %%
print('The {} {} {}'.format('fox','brown','quick'))
# Out:
# The fox brown quick

# %%
print('The {f} {b} {b}'.format(f='fox' , b='brown', q='quick'))
# Out:
# The fox brown brown

# %% [markdown]
# Float Formatting

# %%
result =100/777

# %%
result
# Out:
# 0.1287001287001287

# %%
print(
