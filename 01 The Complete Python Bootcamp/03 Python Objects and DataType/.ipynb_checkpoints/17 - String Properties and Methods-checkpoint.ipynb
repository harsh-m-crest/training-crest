# %% [markdown]
# Immutabilty

# %%
name = "Sam"

# %%
# name[0]="P"

# %%
last_letters = name[1:]

# %%
last_letters
# Out:
# 'am'

# %%
'P' + last_letters
# Out:
# 'Pam'

# %%
x = "Hello World"

# %%
x + " it is beautiful outisde"
# Out:
# 'Hello Worldit is beautiful outisdeit is beautiful outisde it is beautiful outisde'

# %%
x = x + " it is beautiful outisde"

# %%
x
# Out:
# 'Hello Worldit is beautiful outisdeit is beautiful outisde it is beautiful outisde'

# %%
letters = 'z'

# %%
letters * 10
# Out:
# 'zzzzzzzzzz'

# %%
'2' + '3'
# Out:
# '23'

# %%
2 + 3
# Out:
# 5

# %%
x = "Hellow world"

# %%
x.upper()
# Out:
# 'HELLOW WORLD'

# %%
x.upper
# Out:
# <function str.upper()>

# %%
x.split()
# Out:
# ['Hellow', 'world']

# %%
x = "hi this is a string"

# %%
x.split('i')
# Out:
# ['h', ' th', 's ', 's a str', 'ng']
