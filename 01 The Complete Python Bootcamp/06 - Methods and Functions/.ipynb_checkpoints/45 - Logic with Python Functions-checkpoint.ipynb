# %%
28 % 2 == 0
# Out:
# True

# %%
21 % 2 == 0
# Out:
# False

# %%
def even_check(number):
    result = number %2  == 0
    return result

# %%
even_check(20)
# Out:
# True

# %%
even_check(21)
# Out:
# False

# %%
def even_check(number):
    return number %2  == 0

# %%
even_check(17)
# Out:
# False

# %%
even_check(16)
# Out:
# True

# %%
# RETRUN TRUE  IF ANY NUMMBER IS EVEN INSIDE A LIST

# %%
def check_even_list(num_list):

    
    for number in num_list:
        if number % 2 == 0:
            return True
        else:
            pass
    return False

# %%
check_even_list([1,3,5,7])

# %%
check_even_list([2,4,6,8])
# Out:
# True

# %%
def check_even_list(num_list):
# return all the even numbers in a list 

    #placeholder Variables
    even_numbers = []
    
    for number in num_list:
        if number % 2 == 0:
            even_numbers.append(number)
        else:
            pass
    return even_numbers

# %%
check_even_list([1,2,3,4,5])
# Out:
# [2, 4]

# %%
check_even_list([1,3,5,])
# Out:
# []
