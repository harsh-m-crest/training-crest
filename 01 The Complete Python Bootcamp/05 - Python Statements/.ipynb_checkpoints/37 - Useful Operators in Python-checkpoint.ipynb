# %%
mylist = [1,2,3]

# %%
for num in range(0,10,2):
    print(num)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
list(range(0,11,2))
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
index_count = 0

for letter in 'abcde':
    print('At index {} the letter is {}'.format(index_count,letter))
    index_count += 1
# Out:
# At index 0 the letter is (0, 'a')
# At index 1 the letter is (1, 'b')
# At index 2 the letter is (2, 'c')
# At index 3 the letter is (3, 'd')
# At index 4 the letter is (4, 'e')

# %%
index_count = 0
word = 'abcde'
for letter in enumerate(word):
    print(word[index_count])
    index_count += 1
# Out:
# a
# b
# c
# d
# e

# %%
index_count = 0
word = 'abcde'
for index,letter in enumerate(word):
    print(index)
    print(letter)
    print('\n')
# Out:
# 0
# a
#
#
# 1
# b
#
#
# 2
# c
#
#
# 3
# d
#
#
# 4
# e

# %%
mylist1 = [1,2,3]
mylist2 = ['a','b','c']
mylist3 = [100,200,300]

# %%
for item in zip(mylist1, mylist2,mylist3):
    print(item)
# Out:
# (1, 'a', 100)
# (2, 'b', 200)
# (3, 'c', 300)

# %%
list(zip(mylist1,mylist2))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
 2 in [1,2,3]
# Out:
# True

# %%
'x' in ['x','y','z']
# Out:
# True

# %%
'a' in 'a world'
# Out:
# True

# %%
'mykey' in {'mykey': 345}
# Out:
# True

# %%
d = {'mykey': 345}
345 in d.keys()
# Out:
# False

# %%
mylist = [10,20,30,40,100]

# %%
min(mylist)
# Out:
# 10

# %%
max(mylist)
# Out:
# 100

# %%
from random import shuffle

# %%
shuffle(mylist)

# %%
mylist
# Out:
# [30, 40, 20, 100, 10]

# %%
random_list = shuffle(mylist)

# %%
type(random_list)
# Out:
# NoneType

# %%
mylist
# Out:
# [10, 40, 30, 100, 20]

# %%
from random import randint

# %%
randint(0,100)
# Out:
# 4

# %%
randint(0,100)
# Out:
# 51

# %%
mynum= randint(0,10)

# %%
mynum
# Out:
# 5

# %%
result = input('Enter a number here:')
# Out:
# Enter a number here: 7

# %%
result
# Out:
# '7'

# %%
 type(result)
# Out:
# str

# %%
float(result)
# Out:
# 7.0
